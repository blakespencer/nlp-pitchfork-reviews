# %% [markdown]
# ### Natrual Language Processing Project:<br>An exploration into Ptichfork Music Reviews
#
# Blake Spencer<br>
# March 2019
#
# The goal of this project is to understand how music reivews are written, and see if there are differences between genres or how well the review is written.
#
# You can see my blog post about the project here:<br>
# https://blake-spencer-projects.herokuapp.com/nlp
#
# The main steps were: <br>
#
# 1. [Scrape all 21000 reviews and save them in a CSV](https://github.com/blakespencer/nlp-pitchfork-reviews/blob/master/pitchfork_scrape.ipynb)
# 2. [Clean the text] (https://github.com/blakespencer/nlp-pitchfork-reviews/blob/master/cleaning_data.ipynb)
# 3. **Topic modeling by sentence** (this file)
# 4. [Visualize the Data](https://blake-spencer-projects.herokuapp.com/nlp)
#
# Each of the links above is a Jupyter Notebook file with Python code to complete each step.
#
# The Flask App backend:
#
# - [Flask app code in Python](https://github.com/blakespencer/personal-site-backend)
#
# The React App frontend:
#
# - [React app code in Javascript](https://github.com/blakespencer/personal-site-frontend)

# %%
import pickle
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from sklearn.decomposition import NMF
from nltk.tokenize import sent_tokenize
import re
import string
import numpy as np

# %%
with open('df_clean.pkl', 'rb') as picklefile:
    df = pickle.load(picklefile)

# %%
df.head()
# Out:
#    album_score album_year           artist              album_name  \
# 0          9.0       1998         Tortoise                     TNT
# 1          8.1       2019  Various Artists         Powder in Space
# 2          5.6       2019      Perfect Son                    Cast
# 3          7.3       2019      Black Taffy            Elder Mantis
# 4          7.0       2019           Ithaca  The Language of Injury
#
#                                                 text              genres  \
# 0  Imagine a graphic showing all the bands the fi...  Experimental, Rock
# 1  In the 19th century, as unions throughout Amer...            No Genre
# 2  Tobiasz Biliński’s Perfect Son is a descendant...                Rock
# 3  Imagine if the Caretaker were more into RZA th...        Experimental
# 4  Ithaca’s debut is an invitation for whiplash. ...               Metal
#
#         review_date  highly_rated  \
# 0  February 17 2019             1
# 1  February 16 2019             1
# 2  February 16 2019             0
# 3  February 16 2019             1
# 4  February 16 2019             1
#
#                                           text_clean
# 0  imagine a graphic showing all the bands the fi...
# 1  in the   century  as unions throughout america...
# 2  tobiasz biliński perfectson is a descendant of...
# 3  imagine if the caretaker were more into rza th...
# 4  ithaca debut is an invitation for whiplash  th...

# %% [markdown]
# # Topic Modeling by Sentence
# - Topic Modeling by document ended up giving me genre's as topics. I want to see if it's possible to generate topics based on how reviews are written, not by topic

# %%
df['id'] = df['artist'] + df['album_name'] + df['review_date']

# %%
df_sentence = df[['id', 'text']]

# %%
def create_sentence_split(row, data_sentence=[]):
    text_sentences = text.split('.')
    for sentence in text_sentences:
        data_sentence.append([row.id, sentence])

# %%
text_sentences = []

# %%
ids = list(df['id'])
texts = list(df['text'])

# %%
pd.DataFrame(text_sentences)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
artists = list(df['artist'].unique())
artists.append('Joey Bada')
artists.append('Smashing Pumpkins')
artists.append('Jimi Hendrix')
artists.append('Jane s Addiction')
artists.append('Bob Marley')

# %%
def replace_artist_name_v2(text, artists=artists):
    text = text.replace('\n', '')
    for artist in artists:
        if artist in text:
            if(artist == 'The Velvet Underground'):
                artist_name = 'TheVelvetUnderground'
                text = text.replace('Velvet Underground' + ' ', artist_name + " ")
                text = text.replace('Velvet Underground' + '.', artist_name + ".")
                text = text.replace('Velvet Underground' + '!', artist_name + "!")
                text = text.replace('Velvet Underground' + '?', artist_name + "?")
                text = text.replace('Velvets' + ' ', artist_name + ' ')
                text = text.replace('Velvets' + '.', artist_name + ".")
                text = text.replace('Velvets' + '!', artist_name + "!")
                text = text.replace('Velvets' + '?', artist_name + "?")
                
            artist_name = artist.replace(' ', '')
            words = artist.split()
            text = text.replace(artist, artist_name)
            if(len(words) == 2):
                text = text.replace(words[1] + ' ', artist_name + " ")
                text = text.replace(words[1] + '.', artist_name + ".")
                text = text.replace(words[1] + '!', artist_name + "!")
                text = text.replace(words[1] + '?', artist_name + "?")
                if(words[0] != 'The' or 'the'):
                    text = text.replace(words[0] + ' ', artist_name + ' ')
                    text = text.replace(words[0] + '.', artist_name + ".")
                    text = text.replace(words[0] + '!', artist_name + "!")
                    text = text.replace(words[0] + '?', artist_name + "?")
            text = text.replace(words[0]+artist_name, artist_name)
    text = text.replace('-', '')
    return text

# %%
df['text_clean_v2'] = df.text.map(replace_artist_name_v2)

# %% [markdown]
# Now splitting sentences while keeping the id

# %%
def split_sentence(df):
    ids = list(df['id'])
    texts = list(df['text_clean_v2'])
    text_sentences = []
    for idx, review_id in enumerate(ids):
        sentences = sent_tokenize(texts[idx])
        for sentence in sentences:
            text_sentences.append([review_id, sentence])
    return text_sentences

# %%
sentences_from_text = split_sentence(df)

# %%
df_sentences = pd.DataFrame(sentences_from_text, columns=['review_id', 'sentences'])

# %%
df_sentences.head()
# Out:
#                      review_id  \
# 0  TortoiseTNTFebruary 17 2019
# 1  TortoiseTNTFebruary 17 2019
# 2  TortoiseTNTFebruary 17 2019
# 3  TortoiseTNTFebruary 17 2019
# 4  TortoiseTNTFebruary 17 2019
#
#                                            sentences
# 0  Imagine a graphic showing all the bands the fi...
# 1  At the top of the funnel you have groups rangi...
# 2  In this graphic, Tortoise is the choke point, ...
# 3  No album in the band’s initial run embodied th...
# 4  Weirdly beautiful and impossible to pin down, ...

# %%
alphanumeric = lambda x: re.sub('\w*\d\w*', ' ', x)
punc = lambda x: re.sub('[%s]' % re.escape(string.punctuation), ' ', x)
lower = lambda x: x.lower()
no_apostrophy_s = lambda x: re.sub("’s",'', x)

# %%
df_sentences['clean_sentence'] = df_sentences['sentences'].map(alphanumeric).map(punc).map(no_apostrophy_s).map(lower)

# %%
X_sentence = df_sentences['sentences']
y_sentence = df_sentences['review_id']

# %% [markdown]
# Creating Custom Stop Words that don't give topics meaning

# %%
stop_words = ENGLISH_STOP_WORDS.union(['ve',
                                       'music',
                                       'sound',
                                       'fucking',
                                       'fuck',
                                       'pitchfork',
                                       'white',
                                       'en',
                                       'com',
                                       'media',
                                       'backend',
                                       'js',
                                       'tiny_mce',
                                       'themes',
                                       'advanced',
                                       'langs',
                                       'http',
                                       'script',
                                       'chris',
                                       'cornell',
                                       'john',
                                       'velvet',
                                       'underground',
                                       'did'
                                      ])

# %% [markdown]
# Try with different amount of TOPICs and MAX_DFs to see what comes out. Add to Stop Words when appropriate...
# - I settled with 4 topics and a max df of 0.007 since it is done by sentence, max df is very low. If it was bigger, then genre topics would start to form

# %%
cv = CountVectorizer(stop_words=stop_words, max_df=0.007)
X = df_sentences['clean_sentence']

X_cv = cv.fit_transform(X)


pd.DataFrame(X_cv.toarray(), columns=cv.get_feature_names()).head(10)

n_topics = 4

model = NMF(n_components=n_topics)
doc_topic_FOUR_pointseven_percent = model.fit_transform(X_cv)

print(model.components_.shape)


top_ten_words = model.components_.argsort(axis=1)[:,-10:]


for i, row in enumerate(top_ten_words):
    print("topic:",i)
    for x in row:
        print("\t",cv.get_feature_names()[x].strip())
# Out:
# (4, 211279)
# topic: 0
# 	 exactly
# 	 having
# 	 doing
# 	 history
# 	 radio
# 	 stuff
# 	 girl
# 	 fun
# 	 country
# 	 story
# topic: 1
# 	 rhythms
# 	 heavy
# 	 ambient
# 	 familiar
# 	 chords
# 	 sonic
# 	 melodic
# 	 tone
# 	 slow
# 	 synths
# topic: 2
# 	 section
# 	 member
# 	 musicians
# 	 plays
# 	 trio
# 	 members
# 	 vocalist
# 	 bassist
# 	 guitarist
# 	 drummer
# topic: 3
# 	 compilation
# 	 couple
# 	 recordings
# 	 fulllength
# 	 ago
# 	 releases
# 	 previous
# 	 series
# 	 singles
# 	 decade

# %% [markdown]
# Distrobution of topics

# %%
FOUR_pointseven = np.argmax(doc_topic_FOUR_pointseven_percent, axis=1)
    

x = FOUR_pointseven

y = np.bincount(x)
ii = np.nonzero(y)[0]
np.vstack((ii,y[ii])).T
# Out:
# array([[     0, 246627],
#        [     1, 166422],
#        [     2,  11821],
#        [     3,  36663]])

# %% [markdown]
# Now look at the actual sentences to see if topics make sense

# %%
def get_topic(num, x):
    output = []
    for i in list(enumerate(x[:200])):
        if(num == i[1]):
            output.append(i)
    return output

# %%
get_topic(1, FOUR_pointseven)
# Out:
# [(2, 1),
#  (4, 1),
#  (6, 1),
#  (13, 1),
#  (17, 1),
#  (18, 1),
#  (20, 1),
#  (24, 1),
#  (27, 1),
#  (28, 1),
#  (29, 1),
#  (30, 1),
#  (31, 1),
#  (32, 1),
#  (33, 1),
#  (35, 1),
#  (37, 1),
#  (40, 1),
#  (42, 1),
#  (44, 1),
#  (45, 1),
#  (47, 1),
#  (52, 1),
#  (53, 1),
#  (56, 1),
#  (57, 1),
#  (58, 1),
#  (59, 1),
#  (60, 1),
#  (61, 1),
#  (62, 1),
#  (65, 1),
#  (66, 1),
#  (75, 1),
#  (77, 1),
#  (79, 1),
#  (80, 1),
#  (81, 1),
#  (83, 1),
#  (84, 1),
#  (86, 1),
#  (87, 1),
#  (91, 1),
#  (92, 1),
#  (95, 1),
#  (96, 1),
#  (98, 1),
#  (99, 1),
#  (100, 1),
#  (101, 1),
#  (102, 1),
#  (103, 1),
#  (105, 1),
#  (106, 1),
#  (107, 1),
#  (108, 1),
#  (109, 1),
#  (110, 1),
#  (111, 1),
#  (112, 1),
#  (113, 1),
#  (114, 1),
#  (115, 1),
#  (117, 1),
#  (121, 1),
#  (123, 1),
#  (125, 1),
#  (127, 1),
#  (128, 1),
#  (130, 1),
#  (131, 1),
#  (133, 1),
#  (141, 1),
#  (142, 1),
#  (143, 1),
#  (144, 1),
#  (145, 1),
#  (151, 1),
#  (153, 1),
#  (156, 1),
#  (158, 1),
#  (160, 1),
#  (164, 1),
#  (165, 1),
#  (166, 1),
#  (167, 1),
#  (174, 1),
#  (177, 1),
#  (178, 1),
#  (179, 1),
#  (186, 1),
#  (187, 1),
#  (189, 1),
#  (199, 1)]

# %% [markdown]
# Now attach distrobution of topics to actual review

# %%
df_sentences['topic'] = FOUR_pointseven

# %%
df_sentences.head()
# Out:
#                      review_id  \
# 0  TortoiseTNTFebruary 17 2019
# 1  TortoiseTNTFebruary 17 2019
# 2  TortoiseTNTFebruary 17 2019
# 3  TortoiseTNTFebruary 17 2019
# 4  TortoiseTNTFebruary 17 2019
#
#                                            sentences  \
# 0  Imagine a graphic showing all the bands the fi...
# 1  At the top of the funnel you have groups rangi...
# 2  In this graphic, Tortoise is the choke point, ...
# 3  No album in the band’s initial run embodied th...
# 4  Weirdly beautiful and impossible to pin down, ...
#
#                                       clean_sentence  topic
# 0  imagine a graphic showing all the bands the fi...      0
# 1  at the top of the funnel you have groups rangi...      3
# 2  in this graphic  tortoise is the choke point  ...      1
# 3  no album in the band initial run embodied that...      0
# 4  weirdly beautiful and impossible to pin down  ...      1

# %%
df_sentences = pd.get_dummies(df_sentences, columns=['topic'])

# %%
df_sentences.head()
# Out:
#                      review_id  \
# 0  TortoiseTNTFebruary 17 2019
# 1  TortoiseTNTFebruary 17 2019
# 2  TortoiseTNTFebruary 17 2019
# 3  TortoiseTNTFebruary 17 2019
# 4  TortoiseTNTFebruary 17 2019
#
#                                            sentences  \
# 0  Imagine a graphic showing all the bands the fi...
# 1  At the top of the funnel you have groups rangi...
# 2  In this graphic, Tortoise is the choke point, ...
# 3  No album in the band’s initial run embodied th...
# 4  Weirdly beautiful and impossible to pin down, ...
#
#                                       clean_sentence  topic_0  topic_1  \
# 0  imagine a graphic showing all the bands the fi...        1        0
# 1  at the top of the funnel you have groups rangi...        0        0
# 2  in this graphic  tortoise is the choke point  ...        0        1
# 3  no album in the band initial run embodied that...        1        0
# 4  weirdly beautiful and impossible to pin down  ...        0        1
#
#    topic_2  topic_3
# 0        0        0
# 1        0        1
# 2        0        0
# 3        0        0
# 4        0        0

# %%
df_topic_count = df_sentences.groupby(['review_id']).agg({'topic_0': 'sum', 'topic_1': 'sum', 'topic_2': 'sum', 'topic_3': 'sum'})

# %%
df['review_id'] = df['id']

# %%
df_merged = df.merge(df_topic_count, on='review_id')

# %%
df_merged['total'] = df_merged['topic_0'] + df_merged['topic_1'] + df_merged['topic_2'] + df_merged['topic_3']

# %%
df_merged['topic_0'] = df_merged['topic_0'] / df_merged['total']

df_merged['topic_1'] = df_merged['topic_1'] / df_merged['total']

df_merged['topic_2'] = df_merged['topic_2'] / df_merged['total']

df_merged['topic_3'] = df_merged['topic_3'] / df_merged['total']

# %%
df_merged['year'] = df_merged['review_date'].transform(lambda i : i[-4:])

# %%
columns = list(df_merged.columns)

# %%
columns[-3] = 'History/Context'
columns[-4] = 'Artist'
columns[-5] = 'Opinion/Interpretation'
columns[-6] = 'Sound'

# %%
df_merged.columns = columns

# %%
df_merged
# Out:
#        album_score album_year                  artist  \
# 0              9.0       1998                Tortoise
# 1              8.1       2019         Various Artists
# 2              5.6       2019             Perfect Son
# 3              7.3       2019             Black Taffy
# 4              7.0       2019                  Ithaca
# 5              7.7       2019                Ladytron
# 6              7.2       2019     Broken Social Scene
# 7              8.0       2019           Rina Mushonga
# 8              7.8       2019        King Midas Sound
# 9              7.5       2019        Wadada Leo Smith
# 10             8.3       2019                  Nivhek
# 11             7.5       2019             Theon Cross
# 12             7.2       2019    Q Da FoolKenny Beats
# 13             7.6       2019               Ossuarium
# 14             8.0       2019         Default Genders
# 15             6.3       2019     Wiz KhalifaCurren$y
# 16             6.0       2019                 Xiu Xiu
# 17             7.8       2019       Charlotte Adigéry
# 18             7.6       2019              Panda Bear
# 19             7.6       2019             Eli Keszler
# 20             7.7       2019               Navy Blue
# 21             6.4       2019             Hayes Carll
# 22             7.9       2019           Ariana Grande
# 23             3.4       2019                  HEALTH
# 24             6.8       2019               AJ Tracey
# 25             6.9       2019                Hauschka
# 26             8.7       1999             Prince Paul
# 27             8.0       2019            Cass McCombs
# 28             8.0       1991          Laurie Spiegel
# 29             7.4       2019                  Mikron
# ...            ...        ...                     ...
# 20945          6.7         •               Teen Idols
# 20946          8.1         •            Bailter Space
# 20947          8.0         •   The Ladybug Transistor
# 20948          0.2         •                   Wolfie
# 20949          8.0       1999             Songs: Ohia
# 20950          5.4       1999               Cornelius
# 20951          7.5       1999               Cornelius
# 20952          5.5       1999     The Wedding Present
# 20953          8.1       1999                  Looper
# 20954          8.2         •            Damien Jurado
# 20955          7.5       1999            Squarepusher
# 20956          8.0       1999                  Clinic
# 20957          9.4       1999                   Wilco
# 20958          7.4         •                Pan Sonic
# 20959          8.2         •                      XTC
# 20960          7.6         •                  The The
# 20961          5.8         •            Jason Falkner
# 20962          8.5         •             Starflyer 59
# 20963          9.3       1999          Built to Spill
# 20964          8.1       1999         Poster Children
# 20965          7.4       1999                 Sebadoh
# 20966          9.2       1999                Califone
# 20967          8.4         •         Burning Airlines
# 20968          8.0         •       Arling and Cameron
# 20969          7.7       1999                Autechre
# 20970          8.9         •               Sam Prekop
# 20971          7.3         •      John Wesley Harding
# 20972          7.2         •                     Pole
# 20973          4.8         •                  Cassius
# 20974          8.9         •                  Coldcut
#
#                                               album_name  \
# 0                                                    TNT
# 1                                        Powder in Space
# 2                                                   Cast
# 3                                           Elder Mantis
# 4                                 The Language of Injury
# 5                                               Ladytron
# 6                          Let’s Try the After Vol. 1 EP
# 7                                            In a Galaxy
# 8                                               Solitude
# 9      Rosa Parks: Pure Love. An Oratorio of Seven Songs
# 10     After its own death / Walking in a spiral towa...
# 11                                                  Fyah
# 12                                         Bad Influence
# 13                                           Living Tomb
# 14                                    Main Pop Girl 2019
# 15                                                  2009
# 16                             Girl With Basket of Fruit
# 17                                            Zandoli EP
# 18                                                 Buoys
# 19                                             Empire EP
# 20                                      Gangway for Navy
# 21                                            What It Is
# 22                                         thank u, next
# 23                              VOL. 4 :: SLAVES OF FEAR
# 24                                             AJ Tracey
# 25                                    A Different Forest
# 26                                A Prince Among Thieves
# 27                                     Tip of the Sphere
# 28                                         Unseen Worlds
# 29                                             Severance
# ...                                                  ...
# 20945                                         Pucker Up!
# 20946                                            Solar 3
# 20947                                The Albemarle Sound
# 20948                                    Where's Wolfie?
# 20949                                     Axxess and Ace
# 20950                                  CM: Cornelius Mix
# 20951                              FM (Fantasma reMixes)
# 20952                                  Singles 1989-1991
# 20953                                          Up a Tree
# 20954                           Rehearsals for Departure
# 20955                              Budakhan Mindphone EP
# 20956                                             Clinic
# 20957                                        Summerteeth
# 20958                                                  A
# 20959                            Apple Venus, Volume One
# 20960                                  Burning Blue Soul
# 20961                                 Can You Still Feel
# 20962                              Fell in Love at 22 EP
# 20963                              Keep it Like a Secret
# 20964                                   New World Record
# 20965                                        The Sebadoh
# 20966                                           Califone
# 20967                                  Mission: Control!
# 20968                                             All-In
# 20969                                       Peel Session
# 20970                                         Sam Prekop
# 20971                                     Trad Arr Jones
# 20972                                               CD 2
# 20973                                               1999
# 20974                                     Let Us Replay!
#
#                                                     text  \
# 0      Imagine a graphic showing all the bands the fi...
# 1      In the 19th century, as unions throughout Amer...
# 2      Tobiasz Biliński’s Perfect Son is a descendant...
# 3      Imagine if the Caretaker were more into RZA th...
# 4      Ithaca’s debut is an invitation for whiplash. ...
# 5      Two Decembers ago, news viewers were gripped b...
# 6      Given Broken Social Scene’s current status as ...
# 7      Less isn’t always more. In 2014, the Dutch-Zim...
# 8      Kevin Martin’s music has always pursued extrem...
# 9      Trumpeter Wadada Leo Smith has created a bound...
# 10     Liz Harris is just barely audible in her own m...
# 11     At a certain point in a Sons of Kemet live sho...
# 12     Kenny Beats may be the perfect producer for Q ...
# 13     Ossuarium are a very new band with a very old ...
# 14     Over the past decade, James Brooks basically b...
# 15     Wiz Khalifa and Curren$y’s 2009 mixtape How Fl...
# 16     Girl With Basket of Fruit at least sounds incr...
# 17     The Belgium-based French-Caribbean musician Ch...
# 18     When working with Animal Collective, the exube...
# 19     The work of percussionist and composer Eli Kes...
# 20     The man behind the Navy Blue moniker, Sage Els...
# 21     Very few roots singer/songwriters would dare i...
# 22     In 2016, Ariana Grande manifested herself a fu...
# 23     Jacob Duzsik sneers the words “Life is good” o...
# 24     Let us remember London in the early 2000s, a s...
# 25     Feel free to read this sentence a couple of ti...
# 26     Prince Paul is responsible for some of the mos...
# 27     Cass McCombs is open about his tendency to bor...
# 28     When Laurie Spiegel first released her compute...
# 29     Contemporary techno is rarely about anything e...
# ...                                                  ...
# 20945  Well, from the band's namesake alone, we alrea...
# 20946  It's been nearly a month since I saw Bailter S...
# 20947  Something I've come to pay attention to in mus...
# 20948  If this is what independent music has come to,...
# 20949  More melancholy acoustic ballads-- who needs '...
# 20950  Really now, what the last remix album that was...
# 20951  Last year, Japanese crazy artist Cornelius' Am...
# 20952  Less really is more. Take the Wedding Present,...
# 20953  I'm a Looper,\nHe's a Looper,\nShe's a Looper,...
# 20954  Last time we caught up with Damien Jurado, he ...
# 20955  Last year, Squarepusher broke out of the drill...
# 20956  If you've never pondered the source of the rat...
# 20957  After parting ways with Uncle Tupelo partner J...
# 20958  The old joke with Steve Reich's music was that...
# 20959  The concept of late work isn't invoked in too ...
# 20960  Y'know, if only the Trenchcoat Mafia could've ...
# 20961  Jason Falkner: Hello, my name is Jason, and I'...
# 20962  Goddamn, I'm tired. But what do you care? Don'...
# 20963  I hate talking about press kits, but I'm gonna...
# 20964  The Poster Children have been perhaps the most...
# 20965  There's nothing more American than marijuana a...
# 20966  Remember back in elementary school when multim...
# 20967  The ripples from Jawbox's dive into the underg...
# 20968  I got a heart so big it could crush this town....
# 20969  If you know 'em, maybe you love 'em. They're A...
# 20970  I'm psyched. Y'know why? Okay, okay, if you're...
# 20971  Needless to say, the headlines are more than a...
# 20972  When I picked up Pole's first CD (humorlessly ...
# 20973  Well, it's been two weeks now, and I guess it'...
# 20974  The marketing guys of yer average modern megac...
#
#                                genres       review_date  highly_rated  \
# 0                  Experimental, Rock  February 17 2019             1
# 1                            No Genre  February 16 2019             1
# 2                                Rock  February 16 2019             0
# 3                        Experimental  February 16 2019             1
# 4                               Metal  February 16 2019             1
# 5                             Pop/R&B  February 15 2019             1
# 6                                Rock  February 15 2019             1
# 7                             Pop/R&B  February 15 2019             1
# 8                        Experimental  February 15 2019             1
# 9                                Jazz  February 15 2019             1
# 10           Electronic, Experimental  February 14 2019             1
# 11                               Jazz  February 14 2019             1
# 12                                Rap  February 14 2019             1
# 13                              Metal  February 14 2019             1
# 14                         Electronic  February 13 2019             1
# 15                                Rap  February 13 2019             0
# 16                 Experimental, Rock  February 13 2019             0
# 17                       Experimental  February 13 2019             1
# 18                         Electronic  February 12 2019             1
# 19                       Experimental  February 12 2019             1
# 20                                Rap  February 12 2019             1
# 21                       Folk/Country  February 12 2019             0
# 22                            Pop/R&B  February 11 2019             1
# 23                               Rock  February 11 2019             0
# 24                                Rap  February 11 2019             0
# 25                       Experimental  February 11 2019             0
# 26                                Rap  February 10 2019             1
# 27                       Folk/Country   February 9 2019             1
# 28                       Experimental   February 9 2019             1
# 29                         Electronic   February 9 2019             1
# ...                               ...               ...           ...
# 20945                            Rock     March 23 1999             0
# 20946              Experimental, Rock     March 23 1999             1
# 20947                            Rock     March 23 1999             1
# 20948                            Rock     March 23 1999             0
# 20949                            Rock     March 15 1999             1
# 20950                      Electronic      March 9 1999             0
# 20951                      Electronic      March 9 1999             1
# 20952              Experimental, Rock      March 9 1999             0
# 20953                      Electronic      March 9 1999             1
# 20954                            Rock      March 4 1999             1
# 20955                      Electronic      March 2 1999             1
# 20956  Electronic, Experimental, Rock      March 1 1999             1
# 20957                            Rock  February 28 1999             1
# 20958        Electronic, Experimental  February 23 1999             1
# 20959                Electronic, Rock  February 23 1999             1
# 20960                            Rock  February 23 1999             1
# 20961                         Pop/R&B  February 23 1999             0
# 20962                            Rock  February 23 1999             1
# 20963                            Rock  February 23 1999             1
# 20964                            Rock  February 23 1999             1
# 20965              Experimental, Rock  February 23 1999             1
# 20966                            Rock  February 18 1999             1
# 20967                     Metal, Rock  February 16 1999             1
# 20968             Electronic, Pop/R&B  February 11 1999             1
# 20969                      Electronic   February 9 1999             1
# 20970                      Electronic   February 9 1999             1
# 20971                    Folk/Country   February 9 1999             1
# 20972                      Electronic   February 1 1999             1
# 20973                      Electronic   January 26 1999             0
# 20974                Electronic, Jazz   January 26 1999             1
#
#                                               text_clean  \
# 0      imagine a graphic showing all the bands the fi...
# 1      in the   century  as unions throughout america...
# 2      tobiasz biliński perfectson is a descendant of...
# 3      imagine if the caretaker were more into rza th...
# 4      ithaca debut is an invitation for whiplash  th...
# 5      two decembers ago  news viewers were gripped b...
# 6      given brokensocialscene current status as the ...
# 7      less isn’t always more  in    the dutch zimbab...
# 8      kevin martin music has always pursued extremes...
# 9      trumpeter wadadaleosmith has created a boundar...
# 10     liz harris is just barely audible in her own m...
# 11     at a certain point in a sonsofkemet live show ...
# 12     kenny beats may be the perfect producer for q ...
# 13     ossuarium are a very new band with a very old ...
# 14     over the past decade  james brooks basically b...
# 15     wizkhalifa and curren y   mixtape how fly—blog...
# 16     girl with basket of fruit at least sounds incr...
# 17     the belgium based french caribbean musician ch...
# 18     when working with animalcollective  the exuber...
# 19     the work of percussionist and composer elikesz...
# 20     the man behind the navyblue moniker  sage else...
# 21     very few roots singer songwriters would dare i...
# 22     in    arianagrande manifested herself a future...
# 23     jacob duzsik sneers the words “life is good” o...
# 24     let us remember london in the early    a speci...
# 25     feel free to read this sentence a couple of ti...
# 26     princepaul is responsible for some of the most...
# 27     cassmccombs is open about his tendency to borr...
# 28     when lauriespiegel first released her computer...
# 29     contemporary techno is rarely about anything e...
# ...                                                  ...
# 20945  well  from the band s namesake alone  we alrea...
# 20946  it s been nearly a month since i saw bailtersp...
# 20947  something i ve come to pay attention to in mus...
# 20948  if this is what independent music has come to ...
# 20949  more melancholy acoustic ballads   who needs  ...
# 20950  really now  what the last remix album that was...
# 20951  last year  japanese crazy artist cornelius  am...
# 20952  less really is more  take the wedding present ...
# 20953  i m a looper he s a looper she s a looper we r...
# 20954  last time we caught up with damienjurado  he w...
# 20955  last year  squarepusher broke out of the drill...
# 20956  if you ve never pondered the source of the rat...
# 20957  after parting ways with uncletupelo partner ja...
# 20958  the old joke with stevereich s music was that ...
# 20959  the concept of late work isn t invoked in too ...
# 20960  y know  if only the trenchcoat mafia could ve ...
# 20961  jasonfalkner  hello  my name is jasonfalkner  ...
# 20962  goddamn  i m tired  but what do you care  don ...
# 20963  i hate talking about press kits  but i m gonna...
# 20964  the posterchildren have been perhaps the most ...
# 20965  there s nothing more american than marijuana a...
# 20966  remember back in elementary school when multim...
# 20967  the ripples from jawbox s dive into the underg...
# 20968  i got a heart so big it could crush this town ...
# 20969  if you know  em  maybe you love  em  they re a...
# 20970  i m psyched  y know why  okay  okay  if you re...
# 20971  needless to say  the headlines are more than a...
# 20972  when i picked up pole s first cd  humorlessly ...
# 20973  well  it s been two weeks now  and i guess it ...
# 20974  the marketing guys of yer average modern megac...
#
#                                                       id  \
# 0                            TortoiseTNTFebruary 17 2019
# 1         Various ArtistsPowder in SpaceFebruary 16 2019
# 2                        Perfect SonCastFebruary 16 2019
# 3                Black TaffyElder MantisFebruary 16 2019
# 4           IthacaThe Language of InjuryFebruary 16 2019
# 5                       LadytronLadytronFebruary 15 2019
# 6      Broken Social SceneLet’s Try the After Vol. 1 ...
# 7               Rina MushongaIn a GalaxyFebruary 15 2019
# 8               King Midas SoundSolitudeFebruary 15 2019
# 9      Wadada Leo SmithRosa Parks: Pure Love. An Orat...
# 10     NivhekAfter its own death / Walking in a spira...
# 11                       Theon CrossFyahFebruary 14 2019
# 12     Q Da FoolKenny BeatsBad InfluenceFebruary 14 2019
# 13                  OssuariumLiving TombFebruary 14 2019
# 14     Default GendersMain Pop Girl 2019February 13 2019
# 15               Wiz KhalifaCurren$y2009February 13 2019
# 16      Xiu XiuGirl With Basket of FruitFebruary 13 2019
# 17           Charlotte AdigéryZandoli EPFebruary 13 2019
# 18                       Panda BearBuoysFebruary 12 2019
# 19                  Eli KeszlerEmpire EPFebruary 12 2019
# 20             Navy BlueGangway for NavyFebruary 12 2019
# 21                 Hayes CarllWhat It IsFebruary 12 2019
# 22            Ariana Grandethank u, nextFebruary 11 2019
# 23        HEALTHVOL. 4 :: SLAVES OF FEARFebruary 11 2019
# 24                    AJ TraceyAJ TraceyFebruary 11 2019
# 25            HauschkaA Different ForestFebruary 11 2019
# 26     Prince PaulA Prince Among ThievesFebruary 10 2019
# 27          Cass McCombsTip of the SphereFebruary 9 2019
# 28            Laurie SpiegelUnseen WorldsFebruary 9 2019
# 29                        MikronSeveranceFebruary 9 2019
# ...                                                  ...
# 20945                  Teen IdolsPucker Up!March 23 1999
# 20946                  Bailter SpaceSolar 3March 23 1999
# 20947  The Ladybug TransistorThe Albemarle SoundMarch...
# 20948                 WolfieWhere's Wolfie?March 23 1999
# 20949             Songs: OhiaAxxess and AceMarch 15 1999
# 20950             CorneliusCM: Cornelius MixMarch 9 1999
# 20951         CorneliusFM (Fantasma reMixes)March 9 1999
# 20952   The Wedding PresentSingles 1989-1991March 9 1999
# 20953                        LooperUp a TreeMarch 9 1999
# 20954  Damien JuradoRehearsals for DepartureMarch 4 1999
# 20955      SquarepusherBudakhan Mindphone EPMarch 2 1999
# 20956                           ClinicClinicMarch 1 1999
# 20957                   WilcoSummerteethFebruary 28 1999
# 20958                         Pan SonicAFebruary 23 1999
# 20959         XTCApple Venus, Volume OneFebruary 23 1999
# 20960           The TheBurning Blue SoulFebruary 23 1999
# 20961    Jason FalknerCan You Still FeelFebruary 23 1999
# 20962  Starflyer 59Fell in Love at 22 EPFebruary 23 1999
# 20963  Built to SpillKeep it Like a SecretFebruary 23...
# 20964    Poster ChildrenNew World RecordFebruary 23 1999
# 20965                 SebadohThe SebadohFebruary 23 1999
# 20966                   CalifoneCalifoneFebruary 18 1999
# 20967  Burning AirlinesMission: Control!February 16 1999
# 20968           Arling and CameronAll-InFebruary 11 1999
# 20969                AutechrePeel SessionFebruary 9 1999
# 20970                Sam PrekopSam PrekopFebruary 9 1999
# 20971   John Wesley HardingTrad Arr JonesFebruary 9 1999
# 20972                            PoleCD 2February 1 1999
# 20973                         Cassius1999January 26 1999
# 20974               ColdcutLet Us Replay!January 26 1999
#
#                                            text_clean_v2  \
# 0      Imagine a graphic showing all the bands the fi...
# 1      In the 19th century, as unions throughout Amer...
# 2      Tobiasz Biliński’s PerfectSon is a descendant ...
# 3      Imagine if the Caretaker were more into RZA th...
# 4      Ithaca’s debut is an invitation for whiplash. ...
# 5      Two Decembers ago, news viewers were gripped b...
# 6      Given BrokenSocialScene’s current status as th...
# 7      Less isn’t always more. In 2014, the DutchZimb...
# 8      Kevin Martin’s music has always pursued extrem...
# 9      Trumpeter WadadaLeoSmith has created a boundar...
# 10     Liz Harris is just barely audible in her own m...
# 11     At a certain point in a SonsofKemet live show,...
# 12     Kenny Beats may be the perfect producer for Q ...
# 13     Ossuarium are a very new band with a very old ...
# 14     Over the past decade, James Brooks basically b...
# 15     WizKhalifa and Curren$y’s 2009 mixtape How Fly...
# 16     Girl With Basket of Fruit at least sounds incr...
# 17     The Belgiumbased FrenchCaribbean musician Char...
# 18     When working with AnimalCollective, the exuber...
# 19     The work of percussionist and composer EliKesz...
# 20     The man behind the NavyBlue moniker, Sage Else...
# 21     Very few roots singer/songwriters would dare i...
# 22     In 2016, ArianaGrande manifested herself a fut...
# 23     Jacob Duzsik sneers the words “Life is good” o...
# 24     Let us remember London in the early 2000s, a s...
# 25     Feel free to read this sentence a couple of ti...
# 26     PrincePaul is responsible for some of the most...
# 27     CassMcCombs is open about his tendency to borr...
# 28     When LaurieSpiegel first released her computer...
# 29     Contemporary techno is rarely about anything e...
# ...                                                  ...
# 20945  Well, from the band's namesake alone, we alrea...
# 20946  It's been nearly a month since I saw BailterSp...
# 20947  Something I've come to pay attention to in mus...
# 20948  If this is what independent music has come to,...
# 20949  More melancholy acoustic ballads who needs 'em...
# 20950  Really now, what the last remix album that was...
# 20951  Last year, Japanese crazy artist Cornelius' Am...
# 20952  Less really is more. Take the Wedding Present,...
# 20953  I'm a Looper,He's a Looper,She's a Looper,We'r...
# 20954  Last time we caught up with DamienJurado, he w...
# 20955  Last year, Squarepusher broke out of the drill...
# 20956  If you've never pondered the source of the rat...
# 20957  After parting ways with UncleTupelo partner Ja...
# 20958  The old joke with SteveReich's music was that ...
# 20959  The concept of late work isn't invoked in too ...
# 20960  Y'know, if only the Trenchcoat Mafia could've ...
# 20961  JasonFalkner: Hello, my name is Jason, and I'm...
# 20962  Goddamn, I'm tired. But what do you care? Don'...
# 20963  I hate talking about press kits, but I'm gonna...
# 20964  The PosterChildren have been perhaps the most ...
# 20965  There's nothing more American than marijuana a...
# 20966  Remember back in elementary school when multim...
# 20967  The ripples from Jawbox's dive into the underg...
# 20968  I got a heart so big it could crush this town....
# 20969  If you know 'em, maybe you love 'em. They're A...
# 20970  I'm psyched. Y'know why? Okay, okay, if you're...
# 20971  Needless to say, the headlines are more than a...
# 20972  When I picked up Pole's first CD (humorlessly ...
# 20973  Well, it's been two weeks now, and I guess it'...
# 20974  The marketing guys of yer average modern megac...
#
#                                                review_id     Sound  \
# 0                            TortoiseTNTFebruary 17 2019  0.308824
# 1         Various ArtistsPowder in SpaceFebruary 16 2019  0.421053
# 2                        Perfect SonCastFebruary 16 2019  0.545455
# 3                Black TaffyElder MantisFebruary 16 2019  0.000000
# 4           IthacaThe Language of InjuryFebruary 16 2019  0.428571
# 5                       LadytronLadytronFebruary 15 2019  0.550000
# 6      Broken Social SceneLet’s Try the After Vol. 1 ...  0.466667
# 7               Rina MushongaIn a GalaxyFebruary 15 2019  0.590909
# 8               King Midas SoundSolitudeFebruary 15 2019  0.470588
# 9      Wadada Leo SmithRosa Parks: Pure Love. An Orat...  0.363636
# 10     NivhekAfter its own death / Walking in a spira...  0.272727
# 11                       Theon CrossFyahFebruary 14 2019  0.285714
# 12     Q Da FoolKenny BeatsBad InfluenceFebruary 14 2019  0.444444
# 13                  OssuariumLiving TombFebruary 14 2019  0.476190
# 14     Default GendersMain Pop Girl 2019February 13 2019  0.593750
# 15               Wiz KhalifaCurren$y2009February 13 2019  0.625000
# 16      Xiu XiuGirl With Basket of FruitFebruary 13 2019  0.636364
# 17           Charlotte AdigéryZandoli EPFebruary 13 2019  0.384615
# 18                       Panda BearBuoysFebruary 12 2019  0.451613
# 19                  Eli KeszlerEmpire EPFebruary 12 2019  0.090909
# 20             Navy BlueGangway for NavyFebruary 12 2019  0.611111
# 21                 Hayes CarllWhat It IsFebruary 12 2019  0.619048
# 22            Ariana Grandethank u, nextFebruary 11 2019  0.625000
# 23        HEALTHVOL. 4 :: SLAVES OF FEARFebruary 11 2019  0.620690
# 24                    AJ TraceyAJ TraceyFebruary 11 2019  0.421053
# 25            HauschkaA Different ForestFebruary 11 2019  0.176471
# 26     Prince PaulA Prince Among ThievesFebruary 10 2019  0.772727
# 27          Cass McCombsTip of the SphereFebruary 9 2019  0.321429
# 28            Laurie SpiegelUnseen WorldsFebruary 9 2019  0.285714
# 29                        MikronSeveranceFebruary 9 2019  0.318182
# ...                                                  ...       ...
# 20945                  Teen IdolsPucker Up!March 23 1999  0.473684
# 20946                  Bailter SpaceSolar 3March 23 1999  0.500000
# 20947  The Ladybug TransistorThe Albemarle SoundMarch...  0.400000
# 20948                 WolfieWhere's Wolfie?March 23 1999  0.666667
# 20949             Songs: OhiaAxxess and AceMarch 15 1999  0.625000
# 20950             CorneliusCM: Cornelius MixMarch 9 1999  0.380952
# 20951         CorneliusFM (Fantasma reMixes)March 9 1999  0.750000
# 20952   The Wedding PresentSingles 1989-1991March 9 1999  0.708333
# 20953                        LooperUp a TreeMarch 9 1999  0.714286
# 20954  Damien JuradoRehearsals for DepartureMarch 4 1999  0.750000
# 20955      SquarepusherBudakhan Mindphone EPMarch 2 1999  0.375000
# 20956                           ClinicClinicMarch 1 1999  0.705882
# 20957                   WilcoSummerteethFebruary 28 1999  0.703704
# 20958                         Pan SonicAFebruary 23 1999  0.529412
# 20959         XTCApple Venus, Volume OneFebruary 23 1999  0.545455
# 20960           The TheBurning Blue SoulFebruary 23 1999  0.655172
# 20961    Jason FalknerCan You Still FeelFebruary 23 1999  0.782609
# 20962  Starflyer 59Fell in Love at 22 EPFebruary 23 1999  0.809524
# 20963  Built to SpillKeep it Like a SecretFebruary 23...  0.771429
# 20964    Poster ChildrenNew World RecordFebruary 23 1999  0.642857
# 20965                 SebadohThe SebadohFebruary 23 1999  0.708333
# 20966                   CalifoneCalifoneFebruary 18 1999  0.500000
# 20967  Burning AirlinesMission: Control!February 16 1999  0.700000
# 20968           Arling and CameronAll-InFebruary 11 1999  0.593750
# 20969                AutechrePeel SessionFebruary 9 1999  0.696970
# 20970                Sam PrekopSam PrekopFebruary 9 1999  0.666667
# 20971   John Wesley HardingTrad Arr JonesFebruary 9 1999  0.600000
# 20972                            PoleCD 2February 1 1999  0.307692
# 20973                         Cassius1999January 26 1999  0.666667
# 20974               ColdcutLet Us Replay!January 26 1999  0.714286
#
#        Opinion/Interpretation    Artist  History/Context  total  year
# 0                    0.485294  0.058824         0.147059     68  2019
# 1                    0.421053  0.000000         0.157895     19  2019
# 2                    0.454545  0.000000         0.000000     11  2019
# 3                    0.937500  0.000000         0.062500     16  2019
# 4                    0.523810  0.047619         0.000000     21  2019
# 5                    0.350000  0.000000         0.100000     20  2019
# 6                    0.466667  0.000000         0.066667     15  2019
# 7                    0.318182  0.045455         0.045455     22  2019
# 8                    0.352941  0.088235         0.088235     34  2019
# 9                    0.636364  0.000000         0.000000     11  2019
# 10                   0.681818  0.000000         0.045455     22  2019
# 11                   0.642857  0.071429         0.000000     14  2019
# 12                   0.555556  0.000000         0.000000     18  2019
# 13                   0.380952  0.000000         0.142857     21  2019
# 14                   0.312500  0.000000         0.093750     32  2019
# 15                   0.281250  0.000000         0.093750     32  2019
# 16                   0.318182  0.000000         0.045455     22  2019
# 17                   0.615385  0.000000         0.000000     13  2019
# 18                   0.483871  0.000000         0.064516     31  2019
# 19                   0.818182  0.000000         0.090909     22  2019
# 20                   0.333333  0.000000         0.055556     18  2019
# 21                   0.333333  0.000000         0.047619     21  2019
# 22                   0.281250  0.000000         0.093750     32  2019
# 23                   0.344828  0.034483         0.000000     29  2019
# 24                   0.473684  0.000000         0.105263     19  2019
# 25                   0.764706  0.000000         0.058824     17  2019
# 26                   0.166667  0.000000         0.060606     66  2019
# 27                   0.607143  0.000000         0.071429     28  2019
# 28                   0.619048  0.047619         0.047619     21  2019
# 29                   0.500000  0.000000         0.181818     22  2019
# ...                       ...       ...              ...    ...   ...
# 20945                0.421053  0.105263         0.000000     19  1999
# 20946                0.357143  0.071429         0.071429     14  1999
# 20947                0.600000  0.000000         0.000000     15  1999
# 20948                0.274510  0.039216         0.019608     51  1999
# 20949                0.375000  0.000000         0.000000     16  1999
# 20950                0.380952  0.047619         0.190476     21  1999
# 20951                0.200000  0.000000         0.050000     20  1999
# 20952                0.083333  0.041667         0.166667     24  1999
# 20953                0.238095  0.047619         0.000000     21  1999
# 20954                0.250000  0.000000         0.000000     16  1999
# 20955                0.500000  0.000000         0.125000      8  1999
# 20956                0.294118  0.000000         0.000000     17  1999
# 20957                0.296296  0.000000         0.000000     27  1999
# 20958                0.411765  0.000000         0.058824     17  1999
# 20959                0.409091  0.000000         0.045455     22  1999
# 20960                0.275862  0.068966         0.000000     29  1999
# 20961                0.152174  0.043478         0.021739     46  1999
# 20962                0.154762  0.035714         0.000000     84  1999
# 20963                0.171429  0.028571         0.028571     35  1999
# 20964                0.357143  0.000000         0.000000     14  1999
# 20965                0.250000  0.041667         0.000000     24  1999
# 20966                0.428571  0.071429         0.000000     14  1999
# 20967                0.150000  0.075000         0.075000     40  1999
# 20968                0.250000  0.000000         0.156250     32  1999
# 20969                0.242424  0.030303         0.030303     33  1999
# 20970                0.333333  0.000000         0.000000     21  1999
# 20971                0.250000  0.050000         0.100000     20  1999
# 20972                0.384615  0.000000         0.307692     13  1999
# 20973                0.166667  0.000000         0.166667     12  1999
# 20974                0.250000  0.000000         0.035714     28  1999
#
# [20975 rows x 18 columns]

# %%
with open('df_topics.pkl', 'wb') as picklefile:
    pickle.dump(df_merged, picklefile)
